# %% [markdown]
# # Load the data

# %%
# add code here
import pandas as pd

data = pd.read_csv("../../datasets/iris_scaled.csv", header=0, sep=",")
data
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0       -0.900681     1.019004     -1.340227    -1.315444     setosa
# 1       -1.143017    -0.131979     -1.340227    -1.315444     setosa
# 2       -1.385353     0.328414     -1.397064    -1.315444     setosa
# 3       -1.506521     0.098217     -1.283389    -1.315444     setosa
# 4       -1.021849     1.249201     -1.340227    -1.315444     setosa
# ..            ...          ...           ...          ...        ...
# 145      1.038005    -0.131979      0.819596     1.448832  virginica
# 146      0.553333    -1.282963      0.705921     0.922303  virginica
# 147      0.795669    -0.131979      0.819596     1.053935  virginica
# 148      0.432165     0.788808      0.933271     1.448832  virginica
# 149      0.068662    -0.131979      0.762758     0.790671  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Split the data into train and test

# %%
# add code here
from sklearn.model_selection import train_test_split

x = data.iloc[:, 0:4]
y = data.iloc[:, 4]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
x_train.shape, x_test.shape
# Out:
# ((120, 4), (30, 4))

# %% [markdown]
# # Train a Random Forest model

# %%
# add code here
from sklearn.ensemble import RandomForestClassifier

Rf = RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=None, min_samples_split=2, min_samples_leaf=1, max_features='sqrt',
                            bootstrap=True, oob_score=True, random_state=123, verbose=1, class_weight=None)

Rf.fit(x_train, y_train)
Rf
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# RandomForestClassifier(oob_score=True, random_state=123, verbose=1)

# %% [markdown]
# # Draw the 4th tree of the forest

# %%
# add code here
estimator = Rf.estimators_[4]

from sklearn import tree

tree.plot_tree(estimator)
# Out:
# [Text(0.375, 0.9, 'x[3] <= -0.526\ngini = 0.654\nsamples = 76\nvalue = [45, 29, 46]'),
#  Text(0.25, 0.7, 'gini = 0.0\nsamples = 28\nvalue = [45, 0, 0]'),
#  Text(0.5, 0.7, 'x[2] <= 0.564\ngini = 0.474\nsamples = 48\nvalue = [0, 29, 46]'),
#  Text(0.25, 0.5, 'x[0] <= -0.84\ngini = 0.067\nsamples = 19\nvalue = [0, 28, 1]'),
#  Text(0.125, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.375, 0.3, 'gini = 0.0\nsamples = 18\nvalue = [0, 28, 0]'),
#  Text(0.75, 0.5, 'x[2] <= 0.791\ngini = 0.043\nsamples = 29\nvalue = [0, 1, 45]'),
#  Text(0.625, 0.3, 'x[3] <= 0.659\ngini = 0.142\nsamples = 8\nvalue = [0, 1, 12]'),
#  Text(0.5, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.75, 0.1, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 12]'),
#  Text(0.875, 0.3, 'gini = 0.0\nsamples = 21\nvalue = [0, 0, 33]')]

# %% [markdown]
# # Evaluate the model

# %%
# add code here
y_pred = Rf.predict(x_test)

y_pred
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# array(['versicolor', 'setosa', 'virginica', 'versicolor', 'versicolor',
#        'setosa', 'versicolor', 'virginica', 'versicolor', 'versicolor',
#        'virginica', 'setosa', 'setosa', 'setosa', 'setosa', 'versicolor',
#        'virginica', 'versicolor', 'versicolor', 'virginica', 'setosa',
#        'virginica', 'setosa', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'setosa', 'setosa'], dtype=object)

# %% [markdown]
# # Which feature is the most important?

# %%
# add code here

# %% [markdown]
# ## Train and evaluate a AdaBoost model (compare the results with the Random Forest)

# %%
# add code here
