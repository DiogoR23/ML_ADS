# %% [markdown]
# # Data preprocessing exercises

# %%
# Libraries
import pandas as pd
import numpy as np

# %%
# load the wines dataset (datasets/wines.csv)
df_wines = pd.read_csv("../../datasets/wines.csv", header = 0, sep = ",")
# add code here
df_wines
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36   NaN               18.6      101.0           2.80
# 3        NaN        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28   NaN               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      od280/od315_of_diluted_wines  proline  target
# 0                            3.92   1065.0       0
# 1                            3.40   1050.0       0
# 2                            3.17   1185.0       0
# 3                            3.45   1480.0       0
# 4                            2.93    735.0       0
# ..                            ...      ...     ...
# 173                          1.74    740.0       2
# 174                          1.56    750.0       2
# 175                          1.56    835.0       2
# 176                          1.62    840.0       2
# 177                          1.60    560.0       2
#
# [178 rows x 14 columns]

# %%
# check the dimensions of the dataset
# add code here
df_wines.shape
# Out:
# (178, 14)

# %%
# check the first 5 rows of the dataset
# add code here
df_wines.head(5)
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36   NaN               18.6      101.0           2.80
# 3      NaN        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# 0                          3.92   1065.0       0
# 1                          3.40   1050.0       0
# 2                          3.17   1185.0       0
# 3                          3.45   1480.0       0
# 4                          2.93    735.0       0

# %%
# check the data types of the columns
# add code here
df_wines.dtypes
# Out:
# alcohol                         float64
# malic_acid                      float64
# ash                             float64
# alcalinity_of_ash               float64
# magnesium                       float64
# total_phenols                   float64
# flavanoids                      float64
# nonflavanoid_phenols            float64
# proanthocyanins                 float64
# color_intensity                 float64
# hue                             float64
# od280/od315_of_diluted_wines    float64
# proline                         float64
# target                            int64
# dtype: object

# %%
# check the statistical summary of the dataset
# add code here
df_wines.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  163.000000  178.000000  155.000000         178.000000  178.000000
# mean    12.996871    2.336348    2.363290          19.494944   99.741573
# std      0.806567    1.117146    0.281289           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.335000    1.602500    2.205000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.675000    3.082500    2.560000          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# min         0.980000    0.340000              0.130000         0.410000
# 25%         1.742500    1.205000              0.270000         1.250000
# 50%         2.355000    2.135000              0.340000         1.555000
# 75%         2.800000    2.875000              0.437500         1.950000
# max         3.880000    5.080000              0.660000         3.580000
#
#        color_intensity         hue  od280/od315_of_diluted_wines      proline  \
# count       178.000000  178.000000                    178.000000   178.000000
# mean          5.058090    0.957449                      2.611685   746.893258
# std           2.318286    0.228572                      0.709990   314.907474
# min           1.280000    0.480000                      1.270000   278.000000
# 25%           3.220000    0.782500                      1.937500   500.500000
# 50%           4.690000    0.965000                      2.780000   673.500000
# 75%           6.200000    1.120000                      3.170000   985.000000
# max          13.000000    1.710000                      4.000000  1680.000000
#
#            target
# count  178.000000
# mean     0.938202
# std      0.775035
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      2.000000
# max      2.000000

# %%
# check for missing values
# add code here
df_wines.isnull().sum()
# Out:
# alcohol                         15
# malic_acid                       0
# ash                             23
# alcalinity_of_ash                0
# magnesium                        0
# total_phenols                    0
# flavanoids                       0
# nonflavanoid_phenols             0
# proanthocyanins                  0
# color_intensity                  0
# hue                              0
# od280/od315_of_diluted_wines     0
# proline                          0
# target                           0
# dtype: int64

# %%
# create a copy of the dataset and drop the rows with missing values
# add code here
df_wines_missing = df_wines.copy()
df_wines_missing = pd.DataFrame(df_wines_missing)
df_wines_missing.dropna(inplace=True)

# %%
# check the dimensions of the new dataset
# add code here
df_wines_missing.shape
# Out:
# (142, 14)

# %%
# check the statistical summary of the new dataset
# add code here
df_wines_missing.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  142.000000  142.000000  142.000000         142.000000  142.000000
# mean    13.014225    2.364859    2.359155          19.424648   98.830986
# std      0.807203    1.149084    0.285462           3.390876   13.737133
# min     11.030000    0.890000    1.360000          10.600000   70.000000
# 25%     12.362500    1.630000    2.210000          17.025000   88.000000
# 50%     13.050000    1.875000    2.355000          19.450000   97.000000
# 75%     13.705000    3.115000    2.547500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          28.500000  151.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     142.000000  142.000000            142.000000       142.000000
# mean        2.290493    2.017958              0.361127         1.562887
# std         0.619378    1.009242              0.127514         0.564373
# min         0.980000    0.340000              0.130000         0.410000
# 25%         1.782500    1.090000              0.260000         1.150000
# 50%         2.340000    2.155000              0.340000         1.560000
# 75%         2.800000    2.875000              0.450000         1.915000
# max         3.880000    5.080000              0.630000         3.580000
#
#        color_intensity         hue  od280/od315_of_diluted_wines      proline  \
# count       142.000000  142.000000                    142.000000   142.000000
# mean          5.095493    0.955394                      2.607676   732.521127
# std           2.299214    0.225632                      0.720649   300.396658
# min           1.280000    0.480000                      1.270000   278.000000
# 25%           3.255000    0.790000                      1.922500   510.000000
# 50%           4.750000    0.960000                      2.780000   673.500000
# 75%           6.237500    1.105000                      3.177500   907.750000
# max          13.000000    1.710000                      4.000000  1547.000000
#
#            target
# count  142.000000
# mean     0.943662
# std      0.778930
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      2.000000
# max      2.000000

# %%
# check for missing values in the new dataset
# add code here
df_wines_missing.isnull().sum()
# Out:
# alcohol                         0
# malic_acid                      0
# ash                             0
# alcalinity_of_ash               0
# magnesium                       0
# total_phenols                   0
# flavanoids                      0
# nonflavanoid_phenols            0
# proanthocyanins                 0
# color_intensity                 0
# hue                             0
# od280/od315_of_diluted_wines    0
# proline                         0
# target                          0
# dtype: int64

# %%
# create a copy of the dataset and fill the missing values with the median of the respective columns
# add code here
df_wines3 = df_wines.copy()
df_wines3.fillna(df_wines3.median(), inplace=True)
df_wines3.head(5)
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.36               18.6      101.0           2.80
# 3    13.05        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# 0                          3.92   1065.0       0
# 1                          3.40   1050.0       0
# 2                          3.17   1185.0       0
# 3                          3.45   1480.0       0
# 4                          2.93    735.0       0

# %%
# check the statistical summary of the new dataset
# add code here
df_wines3.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.001348    2.336348    2.362865          19.494944   99.741573
# std      0.771776    1.117146    0.262380           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.370000    1.602500    2.242500          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.610000    3.082500    2.517500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# min         0.980000    0.340000              0.130000         0.410000
# 25%         1.742500    1.205000              0.270000         1.250000
# 50%         2.355000    2.135000              0.340000         1.555000
# 75%         2.800000    2.875000              0.437500         1.950000
# max         3.880000    5.080000              0.660000         3.580000
#
#        color_intensity         hue  od280/od315_of_diluted_wines      proline  \
# count       178.000000  178.000000                    178.000000   178.000000
# mean          5.058090    0.957449                      2.611685   746.893258
# std           2.318286    0.228572                      0.709990   314.907474
# min           1.280000    0.480000                      1.270000   278.000000
# 25%           3.220000    0.782500                      1.937500   500.500000
# 50%           4.690000    0.965000                      2.780000   673.500000
# 75%           6.200000    1.120000                      3.170000   985.000000
# max          13.000000    1.710000                      4.000000  1680.000000
#
#            target
# count  178.000000
# mean     0.938202
# std      0.775035
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      2.000000
# max      2.000000

# %%
# check for missing values in the new dataset
# add code here
df_wines3.isnull().sum()
# Out:
# alcohol                         0
# malic_acid                      0
# ash                             0
# alcalinity_of_ash               0
# magnesium                       0
# total_phenols                   0
# flavanoids                      0
# nonflavanoid_phenols            0
# proanthocyanins                 0
# color_intensity                 0
# hue                             0
# od280/od315_of_diluted_wines    0
# proline                         0
# target                          0
# dtype: int64
